# %% [markdown]
# I. Project description: Visualization report for Automatidata to study customer boarding activities across different locations
#
# Aim of project: Identifying boarding activities and patterns using visualizations.
#
# Client: Automatidata
#
# Links: [github link](https://github.com/aniekanekanem/Automatidata-project/blob/main/Activity_Course%203%20Automatidata%20project%20lab.ipynb) for business solution using visualization study and observation for Automatidata
#
#
#
# II. Project description: Visualization report for TikTok to help development of a predictive model that can determine whether a video contains a claim or offers an opinion
#
# Aim of project: To reduce the backlog of user reports and prioritize them more efficiently.
#
# Client: TikTok
#
# Links: [github link](https://github.com/aniekanekanem/TikTok-Project/blob/main/Activity_Course%203%20TikTok%20project%20lab.ipynb) for business solution using visualization study and observation for TikTok
#
#
#
#
# III. Project description: Visualization report for Waze to help prevent user churn on the app.
#
# Aim of project: To prevent user churn on the Waze app.
#
# Client: Waze
#
# Links: [github link](https://github.com/aniekanekanem/Waze-project/blob/main/Activity_Course%203%20Waze%20project%20lab.ipynb) for business solution using visualization study and observation for Waze
